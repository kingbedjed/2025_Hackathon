# %%
from ultralytics import YOLO

# %%
model_1_bestwt = r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\trained_models\yolov11_obb\model_1\weights\best.pt"

# Load a model
model = YOLO("yolo11n-obb.yaml")  # build a new model from YAML
model = YOLO(model_1_bestwt)  # load a pretrained model (recommended for training)
model = YOLO("yolo11n-obb.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data=r"C:\Users\victa\OneDrive\Documents\GitHub\2025_Hackathon\data\dataset_2\model_2_train.yaml", 
                      epochs=500, imgsz=768, patience = 100)
